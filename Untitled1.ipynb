# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

# %%
# !pip install git+https://github.com/tensorflow/examples.git
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://github.com/tensorflow/examples.git
#   Cloning https://github.com/tensorflow/examples.git to c:\users\qxm\appdata\local\temp\pip-req-build-yshutwv7
# Requirement already satisfied (use --upgrade to upgrade): tensorflow-examples===3ed8c6adb8a685d03cb324303a28256d5699a37e- from git+https://github.com/tensorflow/examples.git in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages
# Requirement already satisfied: absl-py in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from tensorflow-examples===3ed8c6adb8a685d03cb324303a28256d5699a37e-) (0.8.1)
# Requirement already satisfied: six in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from tensorflow-examples===3ed8c6adb8a685d03cb324303a28256d5699a37e-) (1.13.0)
# Building wheels for collected packages: tensorflow-examples
#   Building wheel for tensorflow-examples (setup.py): started
#   Building wheel for tensorflow-examples (setup.py): finished with status 'done'
#   Created wheel for tensorflow-examples: filename=tensorflow_examples-3ed8c6adb8a685d03cb324303a28256d5699a37e_-cp37-none-any.whl size=75894 sha256=7aea0a4d11de3f86adc1d1261f6c8ae634d41941a9cc238befda8bf4c9b9d917
#   Stored in directory: C:\Users\qxm\AppData\Local\Temp\pip-ephem-wheel-cache-e3zm9kh_\wheels\83\64\b3\4cfa02dc6f9d16bf7257892c6a7ec602cd7e0ff6ec4d7d714d
# Successfully built tensorflow-examples
#   Running command git clone -q https://github.com/tensorflow/examples.git 'C:\Users\qxm\AppData\Local\Temp\pip-req-build-yshutwv7'

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

from tensorflow_examples.models.pix2pix import pix2pix

import tensorflow_datasets as tfds
tfds.disable_progress_bar()

from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.0.0', with_info=True)
# Out:
# Downloading and preparing dataset oxford_iiit_pet (801.24 MiB) to C:\Users\qxm\tensorflow_datasets\oxford_iiit_pet\3.0.0...
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\http\client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\http\client.py in readinto(self, b)
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionAbortedError: [WinError 10053] 你的主机中的软件中止了一个已建立的连接。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\requests\models.py in generate()
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     528                         # Content-Length are caught.
# --> 529                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     530
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     442                 # This includes IncompleteRead.
# --> 443                 raise ProtocolError("Connection broken: %r" % e, e)
#     444
#
# ProtocolError: ("Connection broken: ConnectionAbortedError(10053, '你的主机中的软件中止了一个已建立的连接。', None, 10053, None)", ConnectionAbortedError(10053, '你的主机中的软件中止了一个已建立的连接。', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-11-e7b40c139e58> in <module>
# ----> 1 dataset, info = tfds.load('oxford_iiit_pet:3.0.0', with_info=True)
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\registered.py in load(name, split, data_dir, batch_size, in_memory, shuffle_files, download, as_supervised, decoders, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     300   if download:
#     301     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 302     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     303
#     304   if as_dataset_kwargs is None:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     285         self._download_and_prepare(
#     286             dl_manager=dl_manager,
# --> 287             download_config=download_config)
#     288
#     289         # NOTE: If modifying the lines below to put additional information in
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#     935     super(GeneratorBasedBuilder, self)._download_and_prepare(
#     936         dl_manager=dl_manager,
# --> 937         max_examples_per_split=download_config.max_examples_per_split,
#     938     )
#     939
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in _download_and_prepare(self, dl_manager, **prepare_split_kwargs)
#     791     # Generating data for all splits
#     792     split_dict = splits_lib.SplitDict()
# --> 793     for split_generator in self._split_generators(dl_manager):
#     794       if splits_lib.Split.ALL == split_generator.split_info.name:
#     795         raise ValueError(
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\image\oxford_iiit_pet.py in _split_generators(self, dl_manager)
#      81         "annotations": tfds.download.Resource(
#      82             url=_BASE_URL + "/annotations.tar.gz",
# ---> 83             extract_method=tfds.download.ExtractMethod.TAR)
#      84     })
#      85
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in download_and_extract(self, url_or_urls)
#     363     with self._downloader.tqdm():
#     364       with self._extractor.tqdm():
# --> 365         return _map_promise(self._download_extract, url_or_urls)
#     366
#     367   @property
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in _map_promise(map_fn, all_inputs)
#     399   """Map the function into each element and resolve the promise."""
#     400   all_promises = utils.map_nested(map_fn, all_inputs)  # Apply the function
# --> 401   res = utils.map_nested(_wait_on_promise, all_promises)
#     402   return res
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\utils\py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     143     return {
#     144         k: map_nested(function, v, dict_only, map_tuple)
# --> 145         for k, v in data_struct.items()
#     146     }
#     147   elif not dict_only:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\utils\py_utils.py in <dictcomp>(.0)
#     143     return {
#     144         k: map_nested(function, v, dict_only, map_tuple)
# --> 145         for k, v in data_struct.items()
#     146     }
#     147   elif not dict_only:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\utils\py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     157         return tuple(mapped)
#     158   # Singleton
# --> 159   return function(data_struct)
#     160
#     161
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in _wait_on_promise(p)
#     383
#     384   def _wait_on_promise(p):
# --> 385     return p.get()
#     386
#     387 else:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\promise\promise.py in get(self, timeout)
#     508         target = self._target()
#     509         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 510         return self._target_settled_value(_raise=True)
#     511
#     512     def _target_settled_value(self, _raise=False):
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\promise\promise.py in _target_settled_value(self, _raise)
#     512     def _target_settled_value(self, _raise=False):
#     513         # type: (bool) -> Any
# --> 514         return self._target()._settled_value(_raise)
#     515
#     516     _value = _reason = _target_settled_value
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\promise\promise.py in _settled_value(self, _raise)
#     222             if _raise:
#     223                 raise_val = self._fulfillment_handler0
# --> 224                 reraise(type(raise_val), raise_val, self._traceback)
#     225             return self._fulfillment_handler0
#     226
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\six.py in reraise(tp, value, tb)
#     694             if value.__traceback__ is not tb:
#     695                 raise value.with_traceback(tb)
# --> 696             raise value
#     697         finally:
#     698             value = None
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\promise\promise.py in handle_future_result(future)
#     840         # type: (Any) -> None
#     841         try:
# --> 842             resolve(future.result())
#     843         except Exception as e:
#     844             tb = exc_info()[2]
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\concurrent\futures\_base.py in result(self, timeout)
#     426                 raise CancelledError()
#     427             elif self._state == FINISHED:
# --> 428                 return self.__get_result()
#     429
#     430             self._condition.wait(timeout)
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\tensorflow_datasets\core\download\downloader.py in _sync_download(self, url, destination_path)
#     248         iterator = response.iter_content(chunk_size=io.DEFAULT_BUFFER_SIZE)
#     249
# --> 250       for block in iterator:
#     251         size += len(block)
#     252
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\requests\models.py in generate()
#     751                         yield chunk
#     752                 except ProtocolError as e:
# --> 753                     raise ChunkedEncodingError(e)
#     754                 except DecodeError as e:
#     755                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionAbortedError(10053, '你的主机中的软件中止了一个已建立的连接。', None, 10053, None)", ConnectionAbortedError(10053, '你的主机中的软件中止了一个已建立的连接。', None, 10053, None))
